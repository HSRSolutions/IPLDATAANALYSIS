# %% [markdown]
# # IPL Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sb

# %%
matches= pd.read_csv('matches.csv')

# %%
m=matches

# %%
deliveries= pd.read_csv('deliveries.csv')

# %%
deliveries

d=deliveries

# %%
print(m.head(1))
print(d.head())
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2 umpire3
# 0  NJ Llong     NaN
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# ...

# %%
# Toss 
m.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
# Program to fetch out all the rows from matches file where that team has won the toss
team=str(input("Enter the team name"))
win = m[m["toss_winner"]== team]
win
# Out:
# Enter the team nameMumbai Indians
#         id  season       city        date                        team1  \
# 6        7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017     Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017     Indore  2017-04-20              Kings XI Punjab
# ..     ...     ...        ...         ...                          ...
# 729  11325    2019      Delhi    18/04/19               Mumbai Indians
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019     Mumbai    05/05/19        Kolkata Knight Riders
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# ...

# %%
# When a team has won the toss as well as won the match

# %%
result=win[win["winner"]== team]

# %%
result[result["result"]=='tie']
# Out:
#         id  season    city      date           team1                team2  \
# 746  11342    2019  Mumbai  02/05/19  Mumbai Indians  Sunrisers Hyderabad
#
#         toss_winner toss_decision result  dl_applied          winner  \
# 746  Mumbai Indians           bat    tie           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match             venue umpire1  \
# 746            0               0       JJ Bumrah  Wankhede Stadium  S Ravi
#
#       umpire2        umpire3
# 746  O Nandan  Nanda Kishore

# %%
m_win=win.count()
r_win=result.count()

# %%
print(m_win)
print(r_win)
# Out:
# id                 98
# season             98
# city               96
# date               98
# team1              98
# team2              98
# toss_winner        98
# toss_decision      98
# result             98
# dl_applied         98
# winner             98
# win_by_runs        98
# win_by_wickets     98
# player_of_match    98
# venue              98
# umpire1            98
# umpire2            98
# umpire3            13
# dtype: int64
# id                 56
# season             56
# city               56
# date               56
# team1              56
# team2              56
# toss_winner        56
# toss_decision      56
# result             56
# dl_applied         56
# winner             56
# win_by_runs        56
# win_by_wickets     56
# player_of_match    56
# venue              56
# umpire1            56
# umpire2            56
# umpire3             8
# dtype: int64

# %%
import matplotlib.pyplot as plt
labels='Win','Loose'
sizes=[56,42]
colors=['green','red']
explode=(0.05,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors, autopct='%1.1f%%',shadow=True
       ,startangle=0)
plt.axis('equal')
plt.show()

# %%
# Analysis on match winning team

# %%
t=str(input("Enter the team name: "))
match_win=m[m['winner']==t]
match_win
# Out:
# Enter the team name: Mumbai Indians
#         id  season       city        date                        team1  \
# 6        7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017     Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017     Indore  2017-04-20              Kings XI Punjab
# ..     ...     ...        ...         ...                          ...
# 739  11335    2019    Chennai    26/04/19               Mumbai Indians
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019     Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019    Chennai    07/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# ...

# %%
# Luck of a team in 2nd inning

# A particular team is winning a match when they are batting in 2nd inning
# First we check that the team has won the toss or not
# If team has won the toss then check toss_decision is field
# If team has loss the toss then check toss_decision is bat

# %%
t1=str(input("Enter the team name: "))
w=m[m["team1"]==t1]
w2=m[m["team2"]==t1]
wf=w.append(w2)
wf
# Out:
# Enter the team name: Mumbai Indians
#         id  season       city        date                        team1  \
# 1        2    2017       Pune  2017-04-06               Mumbai Indians
# 23      24    2017     Mumbai  2017-04-22               Mumbai Indians
# 43      44    2017      Delhi  2017-05-06               Mumbai Indians
# 46      47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 52      53    2017    Kolkata  2017-05-13               Mumbai Indians
# ..     ...     ...        ...         ...                          ...
# 719  11315    2019     Mumbai    10/04/19              Kings XI Punjab
# 726  11322    2019     Mumbai    15/04/19  Royal Challengers Bangalore
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 751  11347    2019     Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019    Chennai    07/05/19          Chennai Super Kings
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
toss_win=wf[wf["toss_winner"]==t1]
toss_win
# Out:
#         id  season            city        date                        team1  \
# 46      47    2017       Hyderabad  2017-05-08               Mumbai Indians
# 58      59    2017       Hyderabad  2017-05-21               Mumbai Indians
# 62      63    2008          Mumbai  2008-04-20               Mumbai Indians
# 131    132    2009  Port Elizabeth  2009-04-27               Mumbai Indians
# 137    138    2009     East London  2009-05-01               Mumbai Indians
# ..     ...     ...             ...         ...                          ...
# 698  11139    2019          Mumbai    24/03/19               Delhi Capitals
# 719  11315    2019          Mumbai    10/04/19              Kings XI Punjab
# 726  11322    2019          Mumbai    15/04/19  Royal Challengers Bangalore
# 742  11338    2019         Kolkata    28/04/19        Kolkata Knight Riders
# 751  11347    2019          Mumbai    05/05/19        Kolkata Knight Riders
#
# ...

# %%
win_field=toss_win[toss_win['toss_decision']=="field"]
win_field
# Out:
#         id  season           city        date                        team1  \
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017         Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017         Indore  2017-04-20              Kings XI Punjab
# 27      28    2017         Mumbai  2017-04-24       Rising Pune Supergiant
# 49      50    2017         Mumbai  2017-05-11              Kings XI Punjab
# 55      56    2017         Mumbai  2017-05-16       Rising Pune Supergiant
# 57      58    2017      Bangalore  2017-05-19        Kolkata Knight Riders
# 66      67    2008        Chennai  2008-04-23          Chennai Super Kings
# 68      69    2008     Chandigarh  2008-04-25              Kings XI Punjab
# ...

# %%
toss_loss=wf[wf["toss_winner"]!=t1]

# %%
loss_field=toss_loss[toss_loss['toss_decision']!="field"]
loss_field
# Out:
#         id  season           city        date                        team1  \
# 33      34    2017         Rajkot  2017-04-29                Gujarat Lions
# 36      37    2017         Mumbai  2017-05-01  Royal Challengers Bangalore
# 74      75    2008        Kolkata  2008-04-29        Kolkata Knight Riders
# 127    128    2009         Durban  2009-04-25              Deccan Chargers
# 134    135    2009         Durban  2009-04-29              Kings XI Punjab
# 146    147    2009      Centurion  2009-05-06              Deccan Chargers
# 156    157    2009      Centurion  2009-05-12              Kings XI Punjab
# 159    160    2009         Durban  2009-05-14             Rajasthan Royals
# 190    191    2010         Mumbai  2010-03-22        Kolkata Knight Riders
# 210    211    2010        Chennai  2010-04-06          Chennai Super Kings
# 233    234    2010         Mumbai  2010-04-25          Chennai Super Kings
# ...

# %%
hsr=win_field.append(loss_field)

# %%
# hsr is a dataframe where Mumbai Indians has batted in the 2nd innings

# %%
hsr.count()
# Out:
# id                 86
# season             86
# city               85
# date               86
# team1              86
# team2              86
# toss_winner        86
# toss_decision      86
# result             86
# dl_applied         86
# winner             86
# win_by_runs        86
# win_by_wickets     86
# player_of_match    86
# venue              86
# umpire1            86
# umpire2            86
# umpire3            11
# dtype: int64

# %%
final=hsr[hsr['winner']==t1]

# %%
# final is the data set where a particular team has batted in 2nd inning and won the toss

# %%
final.count()
# Out:
# id                 51
# season             51
# city               51
# date               51
# team1              51
# team2              51
# toss_winner        51
# toss_decision      51
# result             51
# dl_applied         51
# winner             51
# win_by_runs        51
# win_by_wickets     51
# player_of_match    51
# venue              51
# umpire1            51
# umpire2            51
# umpire3             6
# dtype: int64

# %%
win_percent=(49*100)/95

# %%
win_percent
# Out:
# 51.578947368421055

# %%
import matplotlib.pyplot as plt
labels='Win','Loose'
sizes=[51,35]
colors=['green','red']
explode=(0.05,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors, autopct='%1.1f%%',shadow=True
       ,startangle=0)
plt.axis('equal')
plt.show()

# %%
t1=str(input("Enter the team name: "))
w=m[m["team1"]==t1]
w2=m[m["team2"]==t1]
wf=w.append(w2)
toss_win=wf[wf["toss_winner"]==t1]
win_field=toss_win[toss_win['toss_decision']=="field"]
toss_loss=wf[wf["toss_winner"]!=t1]
loss_field=toss_loss[toss_loss['toss_decision']!="field"]
hsr=win_field.append(loss_field)
final=hsr[hsr['winner']==t1]
final
# Out:
# Enter the team name: Mumbai Indians
#         id  season           city        date                        team1  \
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017         Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017         Indore  2017-04-20              Kings XI Punjab
# 57      58    2017      Bangalore  2017-05-19        Kolkata Knight Riders
# 85      86    2008         Mumbai  2008-05-07             Rajasthan Royals
# 89      90    2008      Bangalore  2008-05-28  Royal Challengers Bangalore
# 95      96    2008         Mumbai  2008-05-14          Chennai Super Kings
# 98      99    2008         Mumbai  2008-05-16        Kolkata Knight Riders
# 193    194    2010         Mumbai  2010-03-25          Chennai Super Kings
# ...

# %%
final.count()
# Out:
# id                 51
# season             51
# city               51
# date               51
# team1              51
# team2              51
# toss_winner        51
# toss_decision      51
# result             51
# dl_applied         51
# winner             51
# win_by_runs        51
# win_by_wickets     51
# player_of_match    51
# venue              51
# umpire1            51
# umpire2            51
# umpire3             6
# dtype: int64

# %%
hsr.count()
# Out:
# id                 86
# season             86
# city               85
# date               86
# team1              86
# team2              86
# toss_winner        86
# toss_decision      86
# result             86
# dl_applied         86
# winner             86
# win_by_runs        86
# win_by_wickets     86
# player_of_match    86
# venue              86
# umpire1            86
# umpire2            86
# umpire3            11
# dtype: int64

# %%
# A team has won the match at their homeground batting in 2nd innings

# %%
final[final['city']=='Hyderabad']
# Out:
#       id  season       city        date                team1           team2  \
# 492  493    2014  Hyderabad  2014-05-12  Sunrisers Hyderabad  Mumbai Indians
# 571  572    2015  Hyderabad  2015-05-17  Sunrisers Hyderabad  Mumbai Indians
#
#              toss_winner toss_decision  result  dl_applied          winner  \
# 492  Sunrisers Hyderabad           bat  normal           0  Mumbai Indians
# 571  Sunrisers Hyderabad           bat  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match  \
# 492            0               7       AT Rayudu
# 571            0               9  MJ McClenaghan
#
#                                          venue          umpire1      umpire2  \
# 492  Rajiv Gandhi International Stadium, Uppal  HDPK Dharmasena  VA Kulkarni
# 571  Rajiv Gandhi International Stadium, Uppal      CB Gaffaney    K Srinath
#
#     umpire3
# 492     NaN
# 571     NaN

# %%
t1=str(input("Enter the team name: "))
city=str(input("Enter the home city of the team: "))
w=m[m["team1"]==t1]
w2=m[m["team2"]==t1]
wf=w.append(w2)
f=wf[wf['winner']==t1]
result=f[f['city']==city]
result
# Out:
# Enter the team name: Mumbai Indians
# Enter the home city of the team: Mumbai
#         id  season    city        date                        team1  \
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 81      82    2008  Mumbai  2008-05-04               Mumbai Indians
# 175    176    2010  Mumbai  2010-03-13               Mumbai Indians
# 198    199    2010  Mumbai  2010-03-28               Mumbai Indians
# 206    207    2010  Mumbai  2010-04-03               Mumbai Indians
# 220    221    2010  Mumbai  2010-04-13               Mumbai Indians
# 230    231    2010  Mumbai  2010-04-21               Mumbai Indians
# 256    257    2011  Mumbai  2011-04-22               Mumbai Indians
# 272    273    2011  Mumbai  2011-05-02               Mumbai Indians
# 276    277    2011  Mumbai  2011-05-04               Mumbai Indians
# 281    282    2011  Mumbai  2011-05-07               Mumbai Indians
# 318    319    2012  Mumbai  2012-04-11               Mumbai Indians
# ...

# %%
result.count()
# Out:
# id                 53
# season             53
# city               53
# date               53
# team1              53
# team2              53
# toss_winner        53
# toss_decision      53
# result             53
# dl_applied         53
# winner             53
# win_by_runs        53
# win_by_wickets     53
# player_of_match    53
# venue              53
# umpire1            53
# umpire2            53
# umpire3             8
# dtype: int64

# %%
wf[wf['city']==city]
# Out:
#         id  season    city        date                        team1  \
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 62      63    2008  Mumbai  2008-04-20               Mumbai Indians
# 71      72    2008  Mumbai  2008-04-27               Mumbai Indians
# 81      82    2008  Mumbai  2008-05-04               Mumbai Indians
# 175    176    2010  Mumbai  2010-03-13               Mumbai Indians
# ..     ...     ...     ...         ...                          ...
# 658   7916    2018  Mumbai    24/04/18          Sunrisers Hyderabad
# 698  11139    2019  Mumbai    24/03/19               Delhi Capitals
# 719  11315    2019  Mumbai    10/04/19              Kings XI Punjab
# 726  11322    2019  Mumbai    15/04/19  Royal Challengers Bangalore
# 751  11347    2019  Mumbai    05/05/19        Kolkata Knight Riders
#
#                            team2       toss_winner toss_decision  result  \
# 23              Delhi Daredevils  Delhi Daredevils         field  normal
# ...

# %%
winperct=(53*100)/82
winperct
# Out:
# 64.63414634146342

# %%
# Session of Data Available in Data

m['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
# Team Won by Maxium Runs

m.iloc[m['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
# Teqm won by Maximum Wickets

m.iloc[m['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
# Team name won by Maximum Runs

m.iloc[m[m['win_by_runs'].ge(1)].win_by_runs.idxmin()]['winner']
# Out:
# 'Mumbai Indians'

# %%
# Team name won by Maximum Wickets

m.iloc[m[m['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
# Number of matches in a season

import matplotlib.pyplot as plt
import seaborn as sb

sb.set_style("darkgrid")
plt.rcParams['figure.figsize'] = (14, 8)

sb.countplot(x='season', data=m)
plt.show()

# %%
# Most match winning team
#sb.countplot(y='winner', data = m)
#plt.show
data = m.winner.value_counts()
sb.barplot(y = data.index, x = data, orient='h');

# %%
m.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
# Top 20 player having most Player of the match

top_players = m.player_of_match.value_counts()[:20]
#sb.barplot(x="day", y="total_bill", data=tips)
fig, ax = plt.subplots()
ax.set_ylim([0,20])
ax.set_ylabel("Player of the match")
ax.set_xlabel("Number of Times")
ax.set_title("Top player of the match Winners")
#top_players.plot.bar()
sb.barplot(x = top_players, y = top_players.index, orient='h'); #palette="Blues");
plt.show()

# %%
# Number of matches won by all team

m.winner.value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
# Toss Winner Match winner

ss = m['toss_winner'] == m['winner']
ss.groupby(ss).size()
# Out:
# False    363
# True     393
# dtype: int64

# %%
# Toss Winner Match Winner for a particular team

hsr=m[m['toss_winner']=='Chennai Super Kings']

sb = hsr['toss_winner'] == hsr['winner']
f=sb.groupby(sb).size()

round(sb.groupby(sb).size() / sb.count() * 100,2)
# Out:
# False    35.96
# True     64.04
# dtype: float64

# %%
# Toss Winner Match Winner Percentage

round(ss.groupby(ss).size() / ss.count() * 100,2)
# Out:
# False    48.02
# True     51.98
# dtype: float64

# %%
# Toss Winner Match Winner Visualization

sb.countplot(ss);

# %%
# Team Performance Batting in first Inning

m[m['win_by_runs']>0].groupby(['winner'])['win_by_runs'].apply(np.median).sort_values(ascending = True)
# Out:
# winner
# Gujarat Lions                   1.0
# Kochi Tuskers Kerala           11.5
# Deccan Chargers                14.5
# Sunrisers Hyderabad            15.5
# Delhi Daredevils               17.0
# Kings XI Punjab                17.0
# Rising Pune Supergiant         20.0
# Royal Challengers Bangalore    20.0
# Pune Warriors                  23.0
# Chennai Super Kings            24.0
# Kolkata Knight Riders          24.5
# Mumbai Indians                 25.0
# Rajasthan Royals               26.0
# Rising Pune Supergiants        26.5
# Delhi Capitals                 37.0
# Name: win_by_runs, dtype: float64

# %%
# Team Performance Batting in second Inning

m[m['win_by_wickets']>0].groupby(['winner'])['win_by_wickets'].apply(np.median).sort_values(ascending = True)
# Out:
# winner
# Delhi Capitals                 5.0
# Chennai Super Kings            6.0
# Deccan Chargers                6.0
# Gujarat Lions                  6.0
# Kings XI Punjab                6.0
# Kolkata Knight Riders          6.0
# Mumbai Indians                 6.0
# Rajasthan Royals               6.0
# Rising Pune Supergiant         6.0
# Delhi Daredevils               6.5
# Pune Warriors                  6.5
# Royal Challengers Bangalore    6.5
# Rising Pune Supergiants        7.0
# Sunrisers Hyderabad            7.0
# Kochi Tuskers Kerala           7.5
# Name: win_by_wickets, dtype: float64

# %%
# Visualization of  Team Performance Batting in second Inning

import seaborn as sb
fig, ax = plt.subplots()

ax.set_title("Winning by Wickets - Team Performance")
sb.barplot(y = 'winner', x = 'win_by_wickets', data=m[m['win_by_wickets']>0], orient = 'h'); #palette="Blues");
plt.show()

# %%
# Visualization of  Team Performance Batting in first Inning

import seaborn as sb
fig, ax = plt.subplots()

ax.set_title("Winning by Runs - Team Performance")
sb.boxplot(y = 'winner', x = 'win_by_runs', data=m[m['win_by_runs']>0], orient = 'h'); #palette="Blues");
plt.show()

# %%
data=m[m['win_by_wickets']>0]
data
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
# Team won by maximum run margin

m.iloc[m['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
# Team won by maximum wickets

m.iloc[m['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
# Batsman Performance in a particular match

condition = d[d['batsman']=='Yuvraj Singh']

x=condition[condition['match_id']==1]
x
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 66          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    11
# 67          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    11
# 69          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    12
# 70          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    12
# 72          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    12
# 73          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    12
# 74          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 75          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 76          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 77          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 78          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# ...

# %%
# Batsman run in match

x.groupby(["match_id"])["batsman_runs"].sum()
# Out:
# match_id
# 10    5
# Name: batsman_runs, dtype: int64

# %%
# Batsman Performance by runs 
file2=d
fours = x[ x["batsman_runs"] == 4]
sixes = x[x["batsman_runs"] == 6]
ones = file2[file2["batsman_runs"]==1]
two = file2[file2["batsman_runs"]==2]
three = file2[file2["batsman_runs"]==3]

fours_per_batsman = fours.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
sixes_per_batsman = sixes.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
ones_per_batsman = ones.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
two_per_batsman = two.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()
three_per_batsman = three.groupby(["match_id", "inning", "batsman"])["batsman_runs"].count()

# %%
# Batsman Performance against a particular Bowler

y=x[x['bowler']=="TS Mills"]
y
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 100         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 101         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 102         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 114         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    19
# 115         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    19
# 116         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    19
#
#      ball       batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 100     2  Yuvraj Singh    DJ Hooda  TS Mills              0  ...         0
# 101     3  Yuvraj Singh    DJ Hooda  TS Mills              0  ...         0
# 102     4  Yuvraj Singh    DJ Hooda  TS Mills              0  ...         0
# 114     2  Yuvraj Singh    DJ Hooda  TS Mills              0  ...         0
# ...

# %%
fours_per_batsman
# Out:
# match_id  inning  batsman
# 1         1       Yuvraj Singh    7
# Name: batsman_runs, dtype: int64

# %%
sixes_per_batsman
# Out:
# match_id  inning  batsman
# 1         1       Yuvraj Singh    3
# Name: batsman_runs, dtype: int64

# %%
# Batsman run against a particular bowler in a particular match

y[y['match_id']==1]["batsman_runs"].sum()
# Out:
# 15

# %%
# Batsman Scoring 50+ runs
z=condition.groupby(['match_id'])["batsman_runs"].sum()
mn=z>=100
mn.groupby(mn).size()

# Yuvraj singh has played total 126 innings and score 36 times 30+ runs and 13 times 50+ runs
# Out:
# batsman_runs
# False    126
# Name: batsman_runs, dtype: int64

# %%
ys = condition[condition["batsman_runs"] == 6]
ys.batsman_runs.value_counts()
# Out:
# 6    149
# Name: batsman_runs, dtype: int64

# %%
# A particlar batsman scored sixes
f=d[d["batsman"]=="Yuvraj Singh"]
c=f[f["batsman_runs"]==6]
c.bowler.value_counts()
# Out:
# SK Warne        7
# AR Patel        6
# YS Chahal       5
# SK Trivedi      4
# Imran Tahir     4
#                ..
# SM Pollock      1
# DE Bollinger    1
# D Salunkhe      1
# K Rabada        1
# NLTC Perera     1
# Name: bowler, Length: 81, dtype: int64

# %%
# Batsman Performance in a match 

condition.batsman_runs.value_counts()
# Out:
# 0    967
# 1    750
# 4    218
# 6    149
# 2    120
# 3      3
# Name: batsman_runs, dtype: int64

# %%
df=condition.batsman_runs.value_counts()
df
# Out:
# 0    967
# 1    750
# 4    218
# 6    149
# 2    120
# 3      3
# Name: batsman_runs, dtype: int64

# %%
condition.batsman_runs.sum()
# Out:
# 2765

# %%
ones=condition[condition['batsman_runs']==6]
ones.batsman_runs.value_counts()
# Out:
# 6    149
# Name: batsman_runs, dtype: int64

# %%
# Batsman Performance

#sb.barplot(x="day", y="total_bill", data=tips)
fig, ax = plt.subplots()
ax.set_ylim([0,7])
ax.set_ylabel("Count")
ax.set_title("Runs Scored by a batsman")
#top_players.plot.bar()
sb.barplot(x = df, y = df.index, orient='h'); #palette="Blues");
plt.show()

# %%
# Dismissal by a bowler

mf=file2[file2['bowler']=='HH Pandya'].player_dismissed.value_counts()
cg=file2[file2['bowler']=='HH Pandya']
mf
# Out:
# S Gill               3
# MK Pandey            2
# MS Dhoni             2
# BA Stokes            2
# SK Raina             2
# N Rana               2
# KK Nair              2
# AD Russell           1
# V Kohli              1
# S Dhawan             1
# PA Patel             1
# MA Agarwal           1
# CA Lynn              1
# SW Billings          1
# KS Williamson        1
# SS Iyer              1
# Yuvraj Singh         1
# AD Mathews           1
# C de Grandhomme      1
# CH Gayle             1
# K Rabada             1
# G Gambhir            1
# SV Samson            1
# Mohammad Nabi        1
# DL Chahar            1
# DA Miller            1
# J Archer             1
# RA Jadeja            1
# KD Karthik           1
# R Parag              1
# AM Rahane            1
# Ankit Sharma         1
# SR Watson            1
# Mandeep Singh        1
# Washington Sundar    1
# Shakib Al Hasan      1
# M Wood               1
# Name: player_dismissed, dtype: int64

# %%
# Dismissal Type by a bowler
cg.dismissal_kind.value_counts()
# Out:
# caught     37
# bowled      4
# run out     3
# lbw         1
# Name: dismissal_kind, dtype: int64

# %%
# Runs given by a bowler

fd=cg.total_runs.value_counts()
fd
# Out:
# 1    361
# 0    287
# 4    115
# 2     85
# 6     58
# 8      4
# 3      3
# 5      1
# Name: total_runs, dtype: int64

# %%
# Visulaization

sb.barplot(x=fd.index,y=fd)

# %%
cg.total_runs.sum()
# Out:
# 1385

# %%
b=cg.dismissal_kind.value_counts()

# %%
sb.barplot(x=b.index,y=b)

# %%
hsr=d[d['batsman_runs']==6]
mnp=hsr[hsr['match_id']==1]
v=mnp[mnp['inning']==1]
v.batsman.value_counts()
# Out:
# Yuvraj Singh    3
# MC Henriques    2
# BCJ Cutting     2
# DJ Hooda        1
# DA Warner       1
# Name: batsman, dtype: int64

# %%
n=d[d["match_id"]==1]
m=n[n["inning"]==2]
m.total_runs.sum()
# Out:
# 172

# %%
file=pd.read_csv("matches.csv")

# %%
file
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...
